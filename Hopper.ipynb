# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("puzzle.csv", header = None)

# %%
#plt.figure()
df.plot(x=0,y=1, kind='scatter')

# %%
plt.show()

# %%
df.plot(x=1,y=0, kind='scatter')
plt.show()

# %% [markdown]
# <img src= http://images.all-free-download.com/images/graphicthumb/simple_world_maps_vector_578784.jpg , width="50%">
